# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir("/nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl")
from travel import init_travel
init_travel()

# %%
import torch
from transformers import BitsAndBytesConfig, AutoModelForSequenceClassification, AutoTokenizer
from transformers import AutoModelForVision2Seq, AutoProcessor
import spacy

from travel.model.nli import NLI_MODEL_PATH

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    llm_int8_threshold=6.0,
    llm_int8_has_fp16_weight=False,
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
)

nli_model = AutoModelForSequenceClassification.from_pretrained(NLI_MODEL_PATH, quantization_config=bnb_config)
nli_tokenizer = AutoTokenizer.from_pretrained(NLI_MODEL_PATH)
nlp = spacy.load("en_core_web_lg")

VLM_NAME = "llava-hf/llava-1.5-7b-hf"
vlm = AutoModelForVision2Seq.from_pretrained(VLM_NAME, 
                                            quantization_config=bnb_config)
vlm_processor = AutoProcessor.from_pretrained(VLM_NAME)
vlm_processor.tokenizer.padding_side = "left"
vlm_processor.tokenizer.pad_token_id = vlm_processor.tokenizer.eos_token_id
# Out:
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
lm = vlm.language_model
tokenizer = vlm_processor.tokenizer

# %% [markdown]
# # Load some outputs

# %%
import json
import os

this_results_dir = "/home/sstorks/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/saved_results_222/vqa_mistake_detection/ego4d_single_debug250/llava-1.5-7b-hf/IterativeVQA_q10_ego4d_single_debug250_llava-1.5-7b-hf_beam8-4_likelihood_nohistory_20240815204213"
# this_results_dir = "/home/sstorks/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/saved_results_222/vqa_mistake_detection/ego4d_single_debug250/llava-1.5-7b-hf/IterativeVQA_topdown_q10_ego4d_single_debug250_llava-1.5-7b-hf_beam8-4_likelihood_nohistory_20240817105952"

all_results_dicts = json.load(open(os.path.join(this_results_dir, "outputs_val.json"), "r"))

# %%
import numpy as np
from tqdm import tqdm

from travel.model.metrics import question_coherence_metrics_nli, compile_accuracy_and_coherence_metrics
from travel.model.mistake_detection import MISTAKE_DETECTION_THRESHOLDS

for turn_idx in tqdm(range(10)):
    
    allturns_results_dir = os.path.join(this_results_dir, f"allturns{turn_idx}")
    if not os.path.exists(allturns_results_dir):
        os.makedirs(allturns_results_dir)
    else:
        continue    
    
    all_probs = [results_dict['success_probs'][turn_idx] for results_dict in all_results_dicts.values()]
    all_labels = [results_dict['mistake'] for results_dict in all_results_dicts.values()]
    
    all_chosen_questions = [question for results_dict in all_results_dicts.values() for question in range(turn_idx+1)]
    all_previous_questions = [[q for qi, q in enumerate(results_dict['questions'][:question_idx]) if results_dict['answers'][qi] != "Unsure"] for results_dict in all_results_dicts.values() for question_idx in range(turn_idx+1)]

    label_answer_mapping = {0: "No", 1: "Yes"}
    all_predicted_answers = [label_answer_mapping[np.argmax(answer_probs)] for results_dict in all_results_dicts.values() for answer_probs in range(turn_idx+1)]
    all_previous_answers = [[a for a in results_dict['answers'][:question_idx] if a != "Unsure"] for results_dict in all_results_dicts.values() for question_idx in range(turn_idx+1)]

    all_coherence_metrics = question_coherence_metrics_nli(nli_tokenizer,
                                                                    nli_model,
                                                                    tokenizer,
                                                                    lm,                                         
                                                                    [results_dict['procedure'] for results_dict in all_results_dicts.values() for _ in range(turn_idx+1)],
                                                                    all_chosen_questions,
                                                                    answers=all_predicted_answers,
                                                                    previous_questions=all_previous_questions,
                                                                    previous_answers=all_previous_answers,
                                                                    mistake_labels=[results_dict['mistake'] for results_dict in all_results_dicts.values() for _ in range(turn_idx+1)],
                                                                    rephrase_batch_size=20)
    
    this_results_dicts = {k: v | {"final_turn": turn_idx} for k, v in all_results_dicts.items()}
    accuracy_metrics_by_threshold, coherence_metrics = compile_accuracy_and_coherence_metrics(all_labels, all_probs, all_coherence_metrics, this_results_dicts, MISTAKE_DETECTION_THRESHOLDS, 0.1)
    
    json.dump(accuracy_metrics_by_threshold, 
            open(os.path.join(allturns_results_dir, f"metrics_accuracy_val.json"), "w"),
            indent=4)

    json.dump(coherence_metrics, 
            open(os.path.join(allturns_results_dir, f"metrics_coherence_nli_val.json"), "w"),
            indent=4)

    json.dump(this_results_dicts, 
            open(os.path.join(allturns_results_dir, f"outputs_val.json"), "w"),
            indent=4)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# running generation (cuda:0):   0%|          | 0/25 [00:00<?, ?it/s]
# running generation (cuda:0):   4%|▍         | 1/25 [00:01<00:40,  1.70s/it]
# running generation (cuda:0):   8%|▊         | 2/25 [00:03<00:39,  1.70s/it]
# running generation (cuda:0):  12%|█▏        | 3/25 [00:05<00:37,  1.71s/it]
# running generation (cuda:0):  16%|█▌        | 4/25 [00:06<00:35,  1.71s/it]
# running generation (cuda:0):  20%|██        | 5/25 [00:08<00:34,  1.71s/it]
# running generation (cuda:0):  24%|██▍       | 6/25 [00:10<00:32,  1.71s/it]
# running generation (cuda:0):  28%|██▊       | 7/25 [00:11<00:30,  1.71s/it]
# running generation (cuda:0):  32%|███▏      | 8/25 [00:13<00:29,  1.71s/it]
# running generation (cuda:0):  36%|███▌      | 9/25 [00:15<00:27,  1.71s/it]
# running generation (cuda:0):  40%|████      | 10/25 [00:17<00:25,  1.71s/it]
# running generation (cuda:0):  44%|████▍     | 11/25 [00:18<00:23,  1.71s/it]
# running generation (cuda:0):  48%|████▊     | 12/25 [00:20<00:22,  1.71s/it]
# running generation (cuda:0):  52%|█████▏    | 13/25 [00:22<00:20,  1.71s/it]
# running generation (cuda:0):  56%|█████▌    | 14/25 [00:23<00:18,  1.71s/it]
# running generation (cuda:0):  60%|██████    | 15/25 [00:25<00:17,  1.71s/it]
# running generation (cuda:0):  64%|██████▍   | 16/25 [00:27<00:15,  1.71s/it]
# running generation (cuda:0):  68%|██████▊   | 17/25 [00:29<00:13,  1.71s/it]
# running generation (cuda:0):  72%|███████▏  | 18/25 [00:30<00:11,  1.71s/it]
# running generation (cuda:0):  76%|███████▌  | 19/25 [00:32<00:10,  1.71s/it]
# running generation (cuda:0):  80%|████████  | 20/25 [00:34<00:08,  1.71s/it]
# running generation (cuda:0):  84%|████████▍ | 21/25 [00:35<00:06,  1.71s/it]
# running generation (cuda:0):  88%|████████▊ | 22/25 [00:37<00:05,  1.71s/it]
# running generation (cuda:0):  92%|█████████▏| 23/25 [00:39<00:03,  1.71s/it]
# running generation (cuda:0):  96%|█████████▌| 24/25 [00:41<00:01,  1.71s/it]
# running generation (cuda:0): 100%|██████████| 25/25 [00:42<00:00,  1.71s/it]
#
# running generation (cuda:0):   0%|          | 0/25 [00:00<?, ?it/s]
# running generation (cuda:0):   4%|▍         | 1/25 [00:03<01:25,  3.56s/it]
# running generation (cuda:0):   8%|▊         | 2/25 [00:07<01:21,  3.56s/it]
# running generation (cuda:0):  12%|█▏        | 3/25 [00:10<01:18,  3.56s/it]
# running generation (cuda:0):  16%|█▌        | 4/25 [00:14<01:14,  3.56s/it]
# running generation (cuda:0):  20%|██        | 5/25 [00:17<01:11,  3.56s/it]
# running generation (cuda:0):  24%|██▍       | 6/25 [00:21<01:07,  3.56s/it]
# running generation (cuda:0):  28%|██▊       | 7/25 [00:24<01:04,  3.56s/it]
# running generation (cuda:0):  32%|███▏      | 8/25 [00:28<01:00,  3.56s/it]
# running generation (cuda:0):  36%|███▌      | 9/25 [00:32<00:57,  3.56s/it]
# running generation (cuda:0):  40%|████      | 10/25 [00:35<00:53,  3.57s/it]
# running generation (cuda:0):  44%|████▍     | 11/25 [00:39<00:49,  3.57s/it]
# running generation (cuda:0):  48%|████▊     | 12/25 [00:42<00:46,  3.57s/it]
# running generation (cuda:0):  52%|█████▏    | 13/25 [00:46<00:42,  3.57s/it]
# running generation (cuda:0):  56%|█████▌    | 14/25 [00:49<00:39,  3.57s/it]
# running generation (cuda:0):  60%|██████    | 15/25 [00:53<00:35,  3.57s/it]
# running generation (cuda:0):  64%|██████▍   | 16/25 [00:57<00:32,  3.57s/it]
# running generation (cuda:0):  68%|██████▊   | 17/25 [01:00<00:28,  3.58s/it]
# running generation (cuda:0):  72%|███████▏  | 18/25 [01:04<00:25,  3.58s/it]
# running generation (cuda:0):  76%|███████▌  | 19/25 [01:07<00:21,  3.58s/it]
# running generation (cuda:0):  80%|████████  | 20/25 [01:11<00:17,  3.58s/it]
# running generation (cuda:0):  84%|████████▍ | 21/25 [01:14<00:14,  3.58s/it]
# running generation (cuda:0):  88%|████████▊ | 22/25 [01:18<00:10,  3.58s/it]
# running generation (cuda:0):  92%|█████████▏| 23/25 [01:22<00:07,  3.58s/it]
# running generation (cuda:0):  96%|█████████▌| 24/25 [01:25<00:03,  3.58s/it]
# running generation (cuda:0): 100%|██████████| 25/25 [01:29<00:00,  3.57s/it]
#
# running NLI (cuda:0):   0%|          | 0/4 [00:00<?, ?it/s]
# running NLI (cuda:0):  50%|█████     | 2/4 [00:00<00:00, 11.79it/s]
# running NLI (cuda:0): 100%|██████████| 4/4 [00:00<00:00, 11.97it/s]
#
# running NLI (cuda:0):   0%|          | 0/4 [00:00<?, ?it/s]
# running NLI (cuda:0):  50%|█████     | 2/4 [00:00<00:00, 11.40it/s]
# running NLI (cuda:0): 100%|██████████| 4/4 [00:00<00:00, 11.54it/s]
#
# running generation (cuda:0): 0it [00:00, ?it/s]
#
# running NLI (cuda:0):   0%|          | 0/4 [00:00<?, ?it/s]
# running NLI (cuda:0):  50%|█████     | 2/4 [00:00<00:00, 11.84it/s]
# running NLI (cuda:0): 100%|██████████| 4/4 [00:00<00:00, 11.99it/s]
#
# running NLI (cuda:0):   0%|          | 0/4 [00:00<?, ?it/s]
# running NLI (cuda:0):  50%|█████     | 2/4 [00:00<00:00, 11.50it/s]
# running NLI (cuda:0): 100%|██████████| 4/4 [00:00<00:00, 11.63it/s]
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
#  10%|█         | 1/10 [02:14<20:08, 134.25s/it]
# running generation (cuda:0):   0%|          | 0/50 [00:00<?, ?it/s]
# running generation (cuda:0):   2%|▏         | 1/50 [00:03<02:54,  3.57s/it]
# running generation (cuda:0):   4%|▍         | 2/50 [00:07<02:51,  3.57s/it]
# running generation (cuda:0):   6%|▌         | 3/50 [00:10<02:47,  3.57s/it]
# running generation (cuda:0):   8%|▊         | 4/50 [00:14<02:44,  3.57s/it]
# running generation (cuda:0):  10%|█         | 5/50 [00:17<02:40,  3.57s/it]
# running generation (cuda:0):  12%|█▏        | 6/50 [00:21<02:37,  3.57s/it]
# running generation (cuda:0):  14%|█▍        | 7/50 [00:25<02:33,  3.58s/it]
# running generation (cuda:0):  16%|█▌        | 8/50 [00:28<02:30,  3.58s/it]
# running generation (cuda:0):  18%|█▊        | 9/50 [00:32<02:26,  3.58s/it]
# running generation (cuda:0):  20%|██        | 10/50 [00:35<02:23,  3.58s/it]
# running generation (cuda:0):  22%|██▏       | 11/50 [00:39<02:19,  3.58s/it]
# running generation (cuda:0):  24%|██▍       | 12/50 [00:42<02:15,  3.58s/it]
# running generation (cuda:0):  26%|██▌       | 13/50 [00:46<02:12,  3.58s/it]
# running generation (cuda:0):  28%|██▊       | 14/50 [00:50<02:08,  3.58s/it]
# running generation (cuda:0):  30%|███       | 15/50 [00:53<02:05,  3.58s/it]
# running generation (cuda:0):  32%|███▏      | 16/50 [00:57<02:01,  3.58s/it]
# running generation (cuda:0):  34%|███▍      | 17/50 [01:00<01:58,  3.58s/it]
# running generation (cuda:0):  36%|███▌      | 18/50 [01:04<01:54,  3.58s/it]
# running generation (cuda:0):  38%|███▊      | 19/50 [01:07<01:50,  3.58s/it]
# running generation (cuda:0):  40%|████      | 20/50 [01:11<01:47,  3.58s/it]
# running generation (cuda:0):  42%|████▏     | 21/50 [01:15<01:43,  3.58s/it]
# running generation (cuda:0):  44%|████▍     | 22/50 [01:18<01:40,  3.58s/it]
# running generation (cuda:0):  46%|████▌     | 23/50 [01:22<01:36,  3.58s/it]
# running generation (cuda:0):  48%|████▊     | 24/50 [01:25<01:32,  3.58s/it]
# running generation (cuda:0):  50%|█████     | 25/50 [01:29<01:29,  3.58s/it]
# running generation (cuda:0):  52%|█████▏    | 26/50 [01:32<01:25,  3.58s/it]
# running generation (cuda:0):  54%|█████▍    | 27/50 [01:36<01:22,  3.58s/it]
# running generation (cuda:0):  56%|█████▌    | 28/50 [01:40<01:18,  3.57s/it]
# running generation (cuda:0):  58%|█████▊    | 29/50 [01:43<01:15,  3.58s/it]
# running generation (cuda:0):  60%|██████    | 30/50 [01:47<01:11,  3.58s/it]
# running generation (cuda:0):  62%|██████▏   | 31/50 [01:50<01:07,  3.58s/it]
# running generation (cuda:0):  64%|██████▍   | 32/50 [01:54<01:04,  3.58s/it]
# running generation (cuda:0):  66%|██████▌   | 33/50 [01:58<01:00,  3.58s/it]
# running generation (cuda:0):  68%|██████▊   | 34/50 [02:01<00:57,  3.58s/it]
# running generation (cuda:0):  70%|███████   | 35/50 [02:05<00:53,  3.58s/it]
# running generation (cuda:0):  72%|███████▏  | 36/50 [02:08<00:50,  3.58s/it]
# running generation (cuda:0):  74%|███████▍  | 37/50 [02:12<00:46,  3.58s/it]
# running generation (cuda:0):  76%|███████▌  | 38/50 [02:15<00:42,  3.58s/it]
# running generation (cuda:0):  78%|███████▊  | 39/50 [02:19<00:39,  3.58s/it]
# running generation (cuda:0):  80%|████████  | 40/50 [02:23<00:35,  3.58s/it]
# running generation (cuda:0):  82%|████████▏ | 41/50 [02:26<00:32,  3.58s/it]
# running generation (cuda:0):  84%|████████▍ | 42/50 [02:30<00:28,  3.58s/it]
# running generation (cuda:0):  86%|████████▌ | 43/50 [02:33<00:25,  3.58s/it]
# running generation (cuda:0):  88%|████████▊ | 44/50 [02:37<00:21,  3.58s/it]
# running generation (cuda:0):  90%|█████████ | 45/50 [02:40<00:17,  3.58s/it]
# running generation (cuda:0):  92%|█████████▏| 46/50 [02:44<00:14,  3.58s/it]
# running generation (cuda:0):  94%|█████████▍| 47/50 [02:48<00:10,  3.58s/it]
# running generation (cuda:0):  96%|█████████▌| 48/50 [02:51<00:07,  3.57s/it]
# running generation (cuda:0):  98%|█████████▊| 49/50 [02:55<00:03,  3.58s/it]
# running generation (cuda:0): 100%|██████████| 50/50 [02:58<00:00,  3.58s/it]
#
# running generation (cuda:0):   0%|          | 0/50 [00:00<?, ?it/s]
# running generation (cuda:0):   2%|▏         | 1/50 [00:03<02:55,  3.58s/it]
# running generation (cuda:0):   4%|▍         | 2/50 [00:07<02:51,  3.58s/it]
# running generation (cuda:0):   6%|▌         | 3/50 [00:10<02:48,  3.58s/it]
# running generation (cuda:0):   8%|▊         | 4/50 [00:14<02:44,  3.58s/it]
# running generation (cuda:0):  10%|█         | 5/50 [00:17<02:40,  3.58s/it]
# running generation (cuda:0):  12%|█▏        | 6/50 [00:21<02:37,  3.58s/it]
# running generation (cuda:0):  14%|█▍        | 7/50 [00:25<02:33,  3.58s/it]
# running generation (cuda:0):  16%|█▌        | 8/50 [00:28<02:30,  3.58s/it]
# running generation (cuda:0):  18%|█▊        | 9/50 [00:32<02:26,  3.58s/it]
# running generation (cuda:0):  20%|██        | 10/50 [00:35<02:23,  3.58s/it]
# running generation (cuda:0):  22%|██▏       | 11/50 [00:39<02:19,  3.58s/it]
# running generation (cuda:0):  24%|██▍       | 12/50 [00:42<02:15,  3.58s/it]
# running generation (cuda:0):  26%|██▌       | 13/50 [00:46<02:12,  3.58s/it]
# running generation (cuda:0):  28%|██▊       | 14/50 [00:50<02:08,  3.58s/it]
# running generation (cuda:0):  30%|███       | 15/50 [00:53<02:05,  3.58s/it]
# running generation (cuda:0):  32%|███▏      | 16/50 [00:57<02:01,  3.58s/it]
# running generation (cuda:0):  34%|███▍      | 17/50 [01:00<01:58,  3.58s/it]
# running generation (cuda:0):  36%|███▌      | 18/50 [01:04<01:54,  3.58s/it]
# running generation (cuda:0):  38%|███▊      | 19/50 [01:07<01:50,  3.58s/it]
# running generation (cuda:0):  40%|████      | 20/50 [01:11<01:47,  3.58s/it]
# running generation (cuda:0):  42%|████▏     | 21/50 [01:15<01:43,  3.58s/it]
# running generation (cuda:0):  44%|████▍     | 22/50 [01:18<01:40,  3.58s/it]
# running generation (cuda:0):  46%|████▌     | 23/50 [01:22<01:36,  3.58s/it]
# running generation (cuda:0):  48%|████▊     | 24/50 [01:25<01:32,  3.58s/it]
# running generation (cuda:0):  50%|█████     | 25/50 [01:29<01:29,  3.58s/it]
# running generation (cuda:0):  52%|█████▏    | 26/50 [01:33<01:25,  3.58s/it]
# running generation (cuda:0):  54%|█████▍    | 27/50 [01:36<01:22,  3.58s/it]
# running generation (cuda:0):  56%|█████▌    | 28/50 [01:40<01:18,  3.58s/it]
# running generation (cuda:0):  58%|█████▊    | 29/50 [01:43<01:15,  3.58s/it]
# running generation (cuda:0):  60%|██████    | 30/50 [01:47<01:11,  3.58s/it]
# running generation (cuda:0):  62%|██████▏   | 31/50 [01:50<01:07,  3.57s/it]
# running generation (cuda:0):  64%|██████▍   | 32/50 [01:54<01:04,  3.58s/it]
# running generation (cuda:0):  66%|██████▌   | 33/50 [01:58<01:00,  3.58s/it]
# running generation (cuda:0):  68%|██████▊   | 34/50 [02:01<00:57,  3.58s/it]
# running generation (cuda:0):  70%|███████   | 35/50 [02:05<00:53,  3.58s/it]
# running generation (cuda:0):  72%|███████▏  | 36/50 [02:08<00:50,  3.58s/it]
# running generation (cuda:0):  74%|███████▍  | 37/50 [02:12<00:46,  3.58s/it]
# running generation (cuda:0):  76%|███████▌  | 38/50 [02:15<00:42,  3.58s/it]
# running generation (cuda:0):  78%|███████▊  | 39/50 [02:19<00:39,  3.58s/it]
# running generation (cuda:0):  80%|████████  | 40/50 [02:23<00:35,  3.58s/it]
# running generation (cuda:0):  82%|████████▏ | 41/50 [02:26<00:32,  3.58s/it]
# running generation (cuda:0):  84%|████████▍ | 42/50 [02:30<00:28,  3.58s/it]
# running generation (cuda:0):  86%|████████▌ | 43/50 [02:33<00:25,  3.58s/it]
# running generation (cuda:0):  88%|████████▊ | 44/50 [02:37<00:21,  3.58s/it]
# running generation (cuda:0):  90%|█████████ | 45/50 [02:40<00:17,  3.58s/it]
# running generation (cuda:0):  92%|█████████▏| 46/50 [02:44<00:14,  3.58s/it]
# running generation (cuda:0):  94%|█████████▍| 47/50 [02:48<00:10,  3.58s/it]
# running generation (cuda:0):  96%|█████████▌| 48/50 [02:51<00:07,  3.58s/it]
# running generation (cuda:0):  98%|█████████▊| 49/50 [02:55<00:03,  3.58s/it]
# running generation (cuda:0): 100%|██████████| 50/50 [02:58<00:00,  3.58s/it]
#
# running NLI (cuda:0):   0%|          | 0/8 [00:00<?, ?it/s]
# running NLI (cuda:0):  25%|██▌       | 2/8 [00:00<00:00, 12.09it/s]
# running NLI (cuda:0):  50%|█████     | 4/8 [00:00<00:00, 12.01it/s]
# running NLI (cuda:0):  75%|███████▌  | 6/8 [00:00<00:00, 11.96it/s]
# running NLI (cuda:0): 100%|██████████| 8/8 [00:00<00:00, 12.14it/s]
#
# running NLI (cuda:0):   0%|          | 0/8 [00:00<?, ?it/s]
# running NLI (cuda:0):  25%|██▌       | 2/8 [00:00<00:00, 11.67it/s]
# running NLI (cuda:0):  50%|█████     | 4/8 [00:00<00:00, 11.72it/s]
# running NLI (cuda:0):  75%|███████▌  | 6/8 [00:00<00:00, 11.66it/s]
# running NLI (cuda:0): 100%|██████████| 8/8 [00:00<00:00, 11.88it/s]
#
# running generation (cuda:0):   0%|          | 0/23 [00:00<?, ?it/s]
# running generation (cuda:0):   4%|▍         | 1/23 [00:03<01:20,  3.67s/it]
# running generation (cuda:0):   9%|▊         | 2/23 [00:07<01:17,  3.67s/it]
# running generation (cuda:0):  13%|█▎        | 3/23 [00:11<01:13,  3.67s/it]
# running generation (cuda:0):  17%|█▋        | 4/23 [00:14<01:09,  3.67s/it]
# running generation (cuda:0):  22%|██▏       | 5/23 [00:18<01:06,  3.68s/it]
# running generation (cuda:0):  26%|██▌       | 6/23 [00:22<01:02,  3.68s/it]
# running generation (cuda:0):  30%|███       | 7/23 [00:25<00:58,  3.68s/it]
# running generation (cuda:0):  35%|███▍      | 8/23 [00:29<00:55,  3.67s/it]
# running generation (cuda:0):  39%|███▉      | 9/23 [00:33<00:51,  3.67s/it]
# running generation (cuda:0):  43%|████▎     | 10/23 [00:36<00:47,  3.67s/it]
# running generation (cuda:0):  48%|████▊     | 11/23 [00:40<00:44,  3.67s/it]
# running generation (cuda:0):  52%|█████▏    | 12/23 [00:44<00:40,  3.67s/it]
# running generation (cuda:0):  57%|█████▋    | 13/23 [00:47<00:36,  3.67s/it]
# running generation (cuda:0):  61%|██████    | 14/23 [00:51<00:33,  3.68s/it]
# running generation (cuda:0):  65%|██████▌   | 15/23 [00:55<00:29,  3.67s/it]
# running generation (cuda:0):  70%|██████▉   | 16/23 [00:58<00:25,  3.67s/it]
# running generation (cuda:0):  74%|███████▍  | 17/23 [01:02<00:22,  3.67s/it]
# running generation (cuda:0):  78%|███████▊  | 18/23 [01:06<00:18,  3.67s/it]
# running generation (cuda:0):  83%|████████▎ | 19/23 [01:09<00:14,  3.67s/it]
# running generation (cuda:0):  87%|████████▋ | 20/23 [01:13<00:11,  3.67s/it]
# running generation (cuda:0):  91%|█████████▏| 21/23 [01:17<00:07,  3.67s/it]
# running generation (cuda:0):  96%|█████████▌| 22/23 [01:20<00:03,  3.67s/it]
# running generation (cuda:0): 100%|██████████| 23/23 [01:23<00:00,  3.63s/it]
#
# running NLI (cuda:0):   0%|          | 0/8 [00:00<?, ?it/s]
# running NLI (cuda:0):  12%|█▎        | 1/8 [00:00<00:00,  9.15it/s]
# running NLI (cuda:0):  25%|██▌       | 2/8 [00:00<00:00,  9.15it/s]
# running NLI (cuda:0):  38%|███▊      | 3/8 [00:00<00:00,  9.23it/s]
# running NLI (cuda:0):  50%|█████     | 4/8 [00:00<00:00,  8.88it/s]
# running NLI (cuda:0):  62%|██████▎   | 5/8 [00:00<00:00,  8.94it/s]
# running NLI (cuda:0):  75%|███████▌  | 6/8 [00:00<00:00,  8.92it/s]
# running NLI (cuda:0): 100%|██████████| 8/8 [00:00<00:00,  9.28it/s]
#
# running NLI (cuda:0):   0%|          | 0/8 [00:00<?, ?it/s]
# running NLI (cuda:0):  12%|█▎        | 1/8 [00:00<00:00,  8.70it/s]
# running NLI (cuda:0):  25%|██▌       | 2/8 [00:00<00:00,  8.76it/s]
# running NLI (cuda:0):  38%|███▊      | 3/8 [00:00<00:00,  8.93it/s]
# running NLI (cuda:0):  50%|█████     | 4/8 [00:00<00:00,  8.70it/s]
# running NLI (cuda:0):  62%|██████▎   | 5/8 [00:00<00:00,  8.76it/s]
# running NLI (cuda:0):  75%|███████▌  | 6/8 [00:00<00:00,  8.77it/s]
# running NLI (cuda:0): 100%|██████████| 8/8 [00:00<00:00,  9.08it/s]
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# /nfs/turbo/coe-chaijy/sstorks/simulation_informed_pcr4nlu/TRAVEl/travel/model/metrics.py:29: RuntimeWarning: invalid value encountered in scalar divide
#   FPR = FP / (FP + TN)
# ...
# running generation (cuda:0):  73%|███████▎  | 570/783 [34:52<13:00,  3.66s/it]
# running generation (cuda:0):  73%|███████▎  | 571/783 [34:56<12:57,  3.67s/it]
# running generation (cuda:0):  73%|███████▎  | 572/783 [35:00<12:52,  3.66s/it]
# running generation (cuda:0):  73%|███████▎  | 573/783 [35:03<12:52,  3.68s/it]
# running generation (cuda:0):  73%|███████▎  | 574/783 [35:07<12:48,  3.68s/it]
# running generation (cuda:0):  73%|███████▎  | 575/783 [35:11<12:44,  3.68s/it]
# running generation (cuda:0):  74%|███████▎  | 576/783 [35:14<12:41,  3.68s/it]
# running generation (cuda:0):  74%|███████▎  | 577/783 [35:18<12:39,  3.69s/it]
# running generation (cuda:0):  74%|███████▍  | 578/783 [35:22<12:34,  3.68s/it]
# running generation (cuda:0):  74%|███████▍  | 579/783 [35:25<12:30,  3.68s/it]
# running generation (cuda:0):  74%|███████▍  | 580/783 [35:29<12:25,  3.67s/it]
# running generation (cuda:0):  74%|███████▍  | 581/783 [35:33<12:21,  3.67s/it]
# running generation (cuda:0):  74%|███████▍  | 582/783 [35:36<12:18,  3.67s/it]
# running generation (cuda:0):  74%|███████▍  | 583/783 [35:40<12:14,  3.67s/it]
# running generation (cuda:0):  75%|███████▍  | 584/783 [35:44<12:06,  3.65s/it]
# running generation (cuda:0):  75%|███████▍  | 585/783 [35:47<12:04,  3.66s/it]
# running generation (cuda:0):  75%|███████▍  | 586/783 [35:51<12:04,  3.68s/it]
# running generation (cuda:0):  75%|███████▍  | 587/783 [35:55<11:58,  3.67s/it]
# running generation (cuda:0):  75%|███████▌  | 588/783 [35:58<11:54,  3.66s/it]
# running generation (cuda:0):  75%|███████▌  | 589/783 [36:02<11:50,  3.66s/it]
# running generation (cuda:0):  75%|███████▌  | 590/783 [36:06<11:49,  3.68s/it]
# running generation (cuda:0):  75%|███████▌  | 591/783 [36:10<11:48,  3.69s/it]
# running generation (cuda:0):  76%|███████▌  | 592/783 [36:13<11:43,  3.68s/it]
# running generation (cuda:0):  76%|███████▌  | 593/783 [36:17<11:39,  3.68s/it]
# running generation (cuda:0):  76%|███████▌  | 594/783 [36:20<11:31,  3.66s/it]
# running generation (cuda:0):  76%|███████▌  | 595/783 [36:24<11:24,  3.64s/it]
# running generation (cuda:0):  76%|███████▌  | 596/783 [36:28<11:22,  3.65s/it]
# running generation (cuda:0):  76%|███████▌  | 597/783 [36:31<11:19,  3.66s/it]
# running generation (cuda:0):  76%|███████▋  | 598/783 [36:35<11:17,  3.66s/it]
# running generation (cuda:0):  77%|███████▋  | 599/783 [36:39<11:14,  3.67s/it]
# running generation (cuda:0):  77%|███████▋  | 600/783 [36:42<11:11,  3.67s/it]
# running generation (cuda:0):  77%|███████▋  | 601/783 [36:46<11:10,  3.68s/it]
# running generation (cuda:0):  77%|███████▋  | 602/783 [36:50<11:08,  3.69s/it]
# running generation (cuda:0):  77%|███████▋  | 603/783 [36:54<11:06,  3.70s/it]
# running generation (cuda:0):  77%|███████▋  | 604/783 [36:57<11:00,  3.69s/it]
# running generation (cuda:0):  77%|███████▋  | 605/783 [37:01<10:58,  3.70s/it]
# running generation (cuda:0):  77%|███████▋  | 606/783 [37:05<10:55,  3.70s/it]
# running generation (cuda:0):  78%|███████▊  | 607/783 [37:08<10:50,  3.70s/it]
# running generation (cuda:0):  78%|███████▊  | 608/783 [37:12<10:47,  3.70s/it]
# running generation (cuda:0):  78%|███████▊  | 609/783 [37:16<10:44,  3.71s/it]
# running generation (cuda:0):  78%|███████▊  | 610/783 [37:19<10:38,  3.69s/it]
# running generation (cuda:0):  78%|███████▊  | 611/783 [37:23<10:32,  3.68s/it]
# running generation (cuda:0):  78%|███████▊  | 612/783 [37:27<10:24,  3.65s/it]
# running generation (cuda:0):  78%|███████▊  | 613/783 [37:30<10:20,  3.65s/it]
# running generation (cuda:0):  78%|███████▊  | 614/783 [37:34<10:17,  3.65s/it]
# running generation (cuda:0):  79%|███████▊  | 615/783 [37:38<10:14,  3.66s/it]
# running generation (cuda:0):  79%|███████▊  | 616/783 [37:41<10:11,  3.66s/it]
# running generation (cuda:0):  79%|███████▉  | 617/783 [37:45<10:07,  3.66s/it]
# running generation (cuda:0):  79%|███████▉  | 618/783 [37:49<10:03,  3.66s/it]
# running generation (cuda:0):  79%|███████▉  | 619/783 [37:52<10:00,  3.66s/it]
# running generation (cuda:0):  79%|███████▉  | 620/783 [37:56<09:57,  3.66s/it]
# running generation (cuda:0):  79%|███████▉  | 621/783 [38:00<09:54,  3.67s/it]
# running generation (cuda:0):  79%|███████▉  | 622/783 [38:03<09:51,  3.67s/it]
# running generation (cuda:0):  80%|███████▉  | 623/783 [38:07<09:46,  3.67s/it]
# running generation (cuda:0):  80%|███████▉  | 624/783 [38:11<09:42,  3.66s/it]
# running generation (cuda:0):  80%|███████▉  | 625/783 [38:14<09:38,  3.66s/it]
# running generation (cuda:0):  80%|███████▉  | 626/783 [38:18<09:35,  3.67s/it]
# running generation (cuda:0):  80%|████████  | 627/783 [38:22<09:31,  3.66s/it]
# running generation (cuda:0):  80%|████████  | 628/783 [38:25<09:27,  3.66s/it]
# running generation (cuda:0):  80%|████████  | 629/783 [38:29<09:23,  3.66s/it]
# running generation (cuda:0):  80%|████████  | 630/783 [38:33<09:19,  3.66s/it]
# running generation (cuda:0):  81%|████████  | 631/783 [38:36<09:16,  3.66s/it]
# running generation (cuda:0):  81%|████████  | 632/783 [38:40<09:13,  3.66s/it]
# running generation (cuda:0):  81%|████████  | 633/783 [38:44<09:06,  3.64s/it]
# running generation (cuda:0):  81%|████████  | 634/783 [38:47<09:03,  3.65s/it]
# running generation (cuda:0):  81%|████████  | 635/783 [38:51<09:00,  3.65s/it]
# running generation (cuda:0):  81%|████████  | 636/783 [38:55<08:57,  3.66s/it]
# running generation (cuda:0):  81%|████████▏ | 637/783 [38:58<08:54,  3.66s/it]
# running generation (cuda:0):  81%|████████▏ | 638/783 [39:02<08:50,  3.66s/it]
# running generation (cuda:0):  82%|████████▏ | 639/783 [39:06<08:46,  3.66s/it]
# running generation (cuda:0):  82%|████████▏ | 640/783 [39:09<08:45,  3.68s/it]
# running generation (cuda:0):  82%|████████▏ | 641/783 [39:13<08:43,  3.69s/it]
# running generation (cuda:0):  82%|████████▏ | 642/783 [39:17<08:41,  3.70s/it]
# running generation (cuda:0):  82%|████████▏ | 643/783 [39:20<08:36,  3.69s/it]
# running generation (cuda:0):  82%|████████▏ | 644/783 [39:24<08:31,  3.68s/it]
# running generation (cuda:0):  82%|████████▏ | 645/783 [39:28<08:26,  3.67s/it]
# running generation (cuda:0):  83%|████████▎ | 646/783 [39:31<08:22,  3.67s/it]
# running generation (cuda:0):  83%|████████▎ | 647/783 [39:35<08:18,  3.66s/it]
# running generation (cuda:0):  83%|████████▎ | 648/783 [39:39<08:13,  3.66s/it]
# running generation (cuda:0):  83%|████████▎ | 649/783 [39:42<08:09,  3.65s/it]
# running generation (cuda:0):  83%|████████▎ | 650/783 [39:46<08:06,  3.66s/it]
# running generation (cuda:0):  83%|████████▎ | 651/783 [39:50<08:03,  3.66s/it]
# running generation (cuda:0):  83%|████████▎ | 652/783 [39:53<08:00,  3.67s/it]
# running generation (cuda:0):  83%|████████▎ | 653/783 [39:57<07:56,  3.67s/it]
# running generation (cuda:0):  84%|████████▎ | 654/783 [40:01<07:53,  3.67s/it]
# running generation (cuda:0):  84%|████████▎ | 655/783 [40:04<07:48,  3.66s/it]
# running generation (cuda:0):  84%|████████▍ | 656/783 [40:08<07:45,  3.66s/it]
# running generation (cuda:0):  84%|████████▍ | 657/783 [40:12<07:42,  3.67s/it]
# running generation (cuda:0):  84%|████████▍ | 658/783 [40:15<07:38,  3.67s/it]
# running generation (cuda:0):  84%|████████▍ | 659/783 [40:19<07:34,  3.67s/it]
# running generation (cuda:0):  84%|████████▍ | 660/783 [40:23<07:32,  3.68s/it]
# running generation (cuda:0):  84%|████████▍ | 661/783 [40:26<07:28,  3.68s/it]
# running generation (cuda:0):  85%|████████▍ | 662/783 [40:30<07:25,  3.68s/it]
# running generation (cuda:0):  85%|████████▍ | 663/783 [40:34<07:20,  3.67s/it]
# running generation (cuda:0):  85%|████████▍ | 664/783 [40:37<07:16,  3.66s/it]
# running generation (cuda:0):  85%|████████▍ | 665/783 [40:41<07:14,  3.68s/it]
# running generation (cuda:0):  85%|████████▌ | 666/783 [40:45<07:11,  3.69s/it]
# running generation (cuda:0):  85%|████████▌ | 667/783 [40:48<07:07,  3.69s/it]
# running generation (cuda:0):  85%|████████▌ | 668/783 [40:52<07:03,  3.68s/it]
# running generation (cuda:0):  85%|████████▌ | 669/783 [40:56<06:59,  3.68s/it]
# running generation (cuda:0):  86%|████████▌ | 670/783 [40:59<06:57,  3.69s/it]
# running generation (cuda:0):  86%|████████▌ | 671/783 [41:03<06:51,  3.68s/it]
# running generation (cuda:0):  86%|████████▌ | 672/783 [41:07<06:48,  3.68s/it]
# running generation (cuda:0):  86%|████████▌ | 673/783 [41:10<06:44,  3.68s/it]
# running generation (cuda:0):  86%|████████▌ | 674/783 [41:14<06:40,  3.68s/it]
# running generation (cuda:0):  86%|████████▌ | 675/783 [41:18<06:37,  3.68s/it]
# running generation (cuda:0):  86%|████████▋ | 676/783 [41:21<06:32,  3.67s/it]
# running generation (cuda:0):  86%|████████▋ | 677/783 [41:25<06:28,  3.67s/it]
# running generation (cuda:0):  87%|████████▋ | 678/783 [41:29<06:25,  3.67s/it]
# running generation (cuda:0):  87%|████████▋ | 679/783 [41:33<06:21,  3.67s/it]
# running generation (cuda:0):  87%|████████▋ | 680/783 [41:36<06:18,  3.67s/it]
# running generation (cuda:0):  87%|████████▋ | 681/783 [41:40<06:13,  3.67s/it]
# running generation (cuda:0):  87%|████████▋ | 682/783 [41:44<06:10,  3.67s/it]
# running generation (cuda:0):  87%|████████▋ | 683/783 [41:47<06:07,  3.67s/it]
# running generation (cuda:0):  87%|████████▋ | 684/783 [41:51<06:03,  3.67s/it]
# running generation (cuda:0):  87%|████████▋ | 685/783 [41:55<05:59,  3.67s/it]
# running generation (cuda:0):  88%|████████▊ | 686/783 [41:58<05:55,  3.67s/it]
# running generation (cuda:0):  88%|████████▊ | 687/783 [42:02<05:52,  3.67s/it]
# running generation (cuda:0):  88%|████████▊ | 688/783 [42:06<05:48,  3.67s/it]
# running generation (cuda:0):  88%|████████▊ | 689/783 [42:09<05:44,  3.67s/it]
# running generation (cuda:0):  88%|████████▊ | 690/783 [42:13<05:41,  3.67s/it]
# running generation (cuda:0):  88%|████████▊ | 691/783 [42:17<05:38,  3.68s/it]
# running generation (cuda:0):  88%|████████▊ | 692/783 [42:20<05:36,  3.69s/it]
# running generation (cuda:0):  89%|████████▊ | 693/783 [42:24<05:32,  3.69s/it]
# running generation (cuda:0):  89%|████████▊ | 694/783 [42:28<05:27,  3.68s/it]
# running generation (cuda:0):  89%|████████▉ | 695/783 [42:31<05:22,  3.67s/it]
# running generation (cuda:0):  89%|████████▉ | 696/783 [42:35<05:19,  3.67s/it]
# running generation (cuda:0):  89%|████████▉ | 697/783 [42:39<05:16,  3.67s/it]
# running generation (cuda:0):  89%|████████▉ | 698/783 [42:42<05:11,  3.67s/it]
# running generation (cuda:0):  89%|████████▉ | 699/783 [42:46<05:07,  3.66s/it]
# running generation (cuda:0):  89%|████████▉ | 700/783 [42:50<05:03,  3.66s/it]
# running generation (cuda:0):  90%|████████▉ | 701/783 [42:53<04:59,  3.66s/it]
# running generation (cuda:0):  90%|████████▉ | 702/783 [42:57<04:56,  3.66s/it]
# running generation (cuda:0):  90%|████████▉ | 703/783 [43:01<04:53,  3.67s/it]
# running generation (cuda:0):  90%|████████▉ | 704/783 [43:04<04:49,  3.67s/it]
# running generation (cuda:0):  90%|█████████ | 705/783 [43:08<04:46,  3.67s/it]
# running generation (cuda:0):  90%|█████████ | 706/783 [43:12<04:42,  3.67s/it]
# running generation (cuda:0):  90%|█████████ | 707/783 [43:15<04:39,  3.67s/it]
# running generation (cuda:0):  90%|█████████ | 708/783 [43:19<04:35,  3.67s/it]
# running generation (cuda:0):  91%|█████████ | 709/783 [43:23<04:31,  3.67s/it]
# running generation (cuda:0):  91%|█████████ | 710/783 [43:26<04:27,  3.67s/it]
# running generation (cuda:0):  91%|█████████ | 711/783 [43:30<04:24,  3.67s/it]
# running generation (cuda:0):  91%|█████████ | 712/783 [43:34<04:20,  3.66s/it]
# running generation (cuda:0):  91%|█████████ | 713/783 [43:37<04:16,  3.66s/it]
# running generation (cuda:0):  91%|█████████ | 714/783 [43:41<04:12,  3.66s/it]
# running generation (cuda:0):  91%|█████████▏| 715/783 [43:45<04:09,  3.66s/it]
# running generation (cuda:0):  91%|█████████▏| 716/783 [43:48<04:05,  3.67s/it]
# running generation (cuda:0):  92%|█████████▏| 717/783 [43:52<04:02,  3.67s/it]
# running generation (cuda:0):  92%|█████████▏| 718/783 [43:56<03:58,  3.66s/it]
# running generation (cuda:0):  92%|█████████▏| 719/783 [43:59<03:54,  3.67s/it]
# running generation (cuda:0):  92%|█████████▏| 720/783 [44:03<03:51,  3.67s/it]
# running generation (cuda:0):  92%|█████████▏| 721/783 [44:07<03:46,  3.65s/it]
# running generation (cuda:0):  92%|█████████▏| 722/783 [44:10<03:42,  3.65s/it]
# running generation (cuda:0):  92%|█████████▏| 723/783 [44:14<03:39,  3.65s/it]
# running generation (cuda:0):  92%|█████████▏| 724/783 [44:18<03:35,  3.65s/it]
# running generation (cuda:0):  93%|█████████▎| 725/783 [44:21<03:32,  3.66s/it]
# running generation (cuda:0):  93%|█████████▎| 726/783 [44:25<03:28,  3.66s/it]
# running generation (cuda:0):  93%|█████████▎| 727/783 [44:29<03:25,  3.67s/it]
# running generation (cuda:0):  93%|█████████▎| 728/783 [44:32<03:21,  3.66s/it]
# running generation (cuda:0):  93%|█████████▎| 729/783 [44:36<03:17,  3.66s/it]
# running generation (cuda:0):  93%|█████████▎| 730/783 [44:39<03:13,  3.66s/it]
# running generation (cuda:0):  93%|█████████▎| 731/783 [44:43<03:11,  3.68s/it]
# running generation (cuda:0):  93%|█████████▎| 732/783 [44:47<03:08,  3.69s/it]
# running generation (cuda:0):  94%|█████████▎| 733/783 [44:51<03:03,  3.68s/it]
# running generation (cuda:0):  94%|█████████▎| 734/783 [44:54<03:00,  3.67s/it]
# running generation (cuda:0):  94%|█████████▍| 735/783 [44:58<02:56,  3.67s/it]
# running generation (cuda:0):  94%|█████████▍| 736/783 [45:02<02:53,  3.69s/it]
# running generation (cuda:0):  94%|█████████▍| 737/783 [45:05<02:49,  3.68s/it]
# running generation (cuda:0):  94%|█████████▍| 738/783 [45:09<02:45,  3.68s/it]
# running generation (cuda:0):  94%|█████████▍| 739/783 [45:13<02:41,  3.68s/it]
# running generation (cuda:0):  95%|█████████▍| 740/783 [45:16<02:38,  3.68s/it]
# running generation (cuda:0):  95%|█████████▍| 741/783 [45:20<02:34,  3.68s/it]
# running generation (cuda:0):  95%|█████████▍| 742/783 [45:24<02:30,  3.68s/it]
# running generation (cuda:0):  95%|█████████▍| 743/783 [45:27<02:27,  3.69s/it]
# running generation (cuda:0):  95%|█████████▌| 744/783 [45:31<02:24,  3.70s/it]
# running generation (cuda:0):  95%|█████████▌| 745/783 [45:35<02:20,  3.70s/it]
# running generation (cuda:0):  95%|█████████▌| 746/783 [45:39<02:17,  3.71s/it]
# running generation (cuda:0):  95%|█████████▌| 747/783 [45:42<02:13,  3.70s/it]
# running generation (cuda:0):  96%|█████████▌| 748/783 [45:46<02:08,  3.68s/it]
# running generation (cuda:0):  96%|█████████▌| 749/783 [45:50<02:05,  3.68s/it]
# running generation (cuda:0):  96%|█████████▌| 750/783 [45:53<02:01,  3.67s/it]
# running generation (cuda:0):  96%|█████████▌| 751/783 [45:57<01:57,  3.67s/it]
# running generation (cuda:0):  96%|█████████▌| 752/783 [46:01<01:53,  3.67s/it]
# running generation (cuda:0):  96%|█████████▌| 753/783 [46:04<01:49,  3.66s/it]
# running generation (cuda:0):  96%|█████████▋| 754/783 [46:08<01:46,  3.66s/it]
# running generation (cuda:0):  96%|█████████▋| 755/783 [46:12<01:42,  3.67s/it]
# running generation (cuda:0):  97%|█████████▋| 756/783 [46:15<01:39,  3.67s/it]
# running generation (cuda:0):  97%|█████████▋| 757/783 [46:19<01:35,  3.67s/it]
# running generation (cuda:0):  97%|█████████▋| 758/783 [46:23<01:31,  3.66s/it]
# running generation (cuda:0):  97%|█████████▋| 759/783 [46:26<01:27,  3.66s/it]
# running generation (cuda:0):  97%|█████████▋| 760/783 [46:30<01:24,  3.66s/it]
# running generation (cuda:0):  97%|█████████▋| 761/783 [46:33<01:20,  3.65s/it]
# running generation (cuda:0):  97%|█████████▋| 762/783 [46:37<01:16,  3.65s/it]
# running generation (cuda:0):  97%|█████████▋| 763/783 [46:41<01:13,  3.65s/it]
# running generation (cuda:0):  98%|█████████▊| 764/783 [46:44<01:09,  3.65s/it]
# running generation (cuda:0):  98%|█████████▊| 765/783 [46:48<01:05,  3.65s/it]
# running generation (cuda:0):  98%|█████████▊| 766/783 [46:52<01:02,  3.65s/it]
# running generation (cuda:0):  98%|█████████▊| 767/783 [46:55<00:58,  3.65s/it]
# running generation (cuda:0):  98%|█████████▊| 768/783 [46:59<00:54,  3.65s/it]
# running generation (cuda:0):  98%|█████████▊| 769/783 [47:03<00:51,  3.65s/it]
# running generation (cuda:0):  98%|█████████▊| 770/783 [47:06<00:47,  3.65s/it]
# running generation (cuda:0):  98%|█████████▊| 771/783 [47:10<00:43,  3.65s/it]

# %%
max_accuracy = None
max_accuracy_turn = None

max_verifiability = None
max_verifiability_turn = None

for turn_idx in tqdm(range(10)):

    accuracy_metrics_by_threshold = json.load(open(os.path.join(allturns_results_dir, f"metrics_accuracy_val.json"), "r"))
    coherence_metrics = json.load(open(os.path.join(allturns_results_dir, f"metrics_coherence_nli_val.json"), "r"))
    
    this_accuracy = accuracy_metrics_by_threshold['best_metrics']['accuracy']
    this_verifiability = max(list(coherence_metrics['metrics_by_threshold'].values()), key=lambda x: x['verifiability'])['verifiability']
    
    if max_accuracy is None or this_accuracy > max_accuracy:
        max_accuracy = this_accuracy
        max_accuracy_turn = turn_idx
        
    if max_verifiability is None or this_verifiability > max_verifiability:
        max_verifiability = this_verifiability
        max_verifiability_turn = turn_idx

# %%
lines = []
lines.append(f"Max accuracy: {max_accuracy} at turn {max_accuracy_turn}")
lines.append(f"Max verifiability: {max_verifiability} at turn {max_verifiability_turn}")

with open(os.path.join(this_results_dir, "allturns_results.txt"), "w") as f:
    f.write("\n".join(lines))
